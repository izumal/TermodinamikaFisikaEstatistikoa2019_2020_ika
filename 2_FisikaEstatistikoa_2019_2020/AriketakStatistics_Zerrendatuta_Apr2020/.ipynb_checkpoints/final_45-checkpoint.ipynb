# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
#    <h1> 12 Ariketa: kokapena </h1>
#
#    <h2> Ariketaren titulua   </h2>
#
#    <h2> Helburua:    </h2>
#
#    $F =  - A\,N^{\frac{2}{3}} V^{\frac{1}{3}} T^2$ lortzea.
#
#    <hr>
#
#    <h2> Ikasiko duzuna:  </h2>
#
#    Honako hau ikasiko duzu: $\frac{1}{3} T^2$
#
# </div>
#
# <div class="row alert alert-info"  role="alert">
#    <br>
#    <br>
#
#    Aztertu beharreko sistemari dagokion oinarrizko ekuazioa ondokoa da:
#
#    $$D_{3}(\epsilon)=\left[\frac{1}{\left(\frac{\pi}{L}\right)}\left(\frac{2m}{\hbar^{2}}\right)^{\frac{1}{2}}\right]\epsilon^{\frac{1}{2}}$$
#
#    adierazpen horretan $A$ konstante positiboa da.
#
#    Bolumena zortzi aldiz handitu dion espantsio adiabatiko itzulgarriaren ondorioz, zenbatekoa da sisteman gertatu den tenperatura-aldaketa?
#
#    1. kkakak
#    2. lallala
#    3. lslls
#
#    <br>
#    <br>
#
# </div>
#
# <p>
# <button class="btn btn-warning" type="button" data-toggle="collapse" data-target="#emaitza5" aria-expanded="false" aria-controls="collapseExample">
#     Emaitza
# </button>
# <button class="btn btn-info" type="button" data-toggle="collapse" data-target="#pistak5" aria-expanded="false" aria-controls="collapseExample">
#     Pistarik...
# </button>
# <button class="btn btn-success" type="button" data-toggle="collapse" data-target="#ebazpena5" aria-expanded="false" aria-controls="collapseExample">
#     Ebazpen bat...
# </button>
# </p>
#
# <div class="collapse" id="emaitza5">
#    <div class="card card-block">
#    <br>
#
#    $pV\equiv\mathscr{\Xi}=-(k_{B}T) \ln[\mathscr{Z}(z,T,V)]$
#
#    <br>
#
#    </div>
# </div>
#
# <div class="collapse" id="pistak5">
#    <div class="card card-block">
#
#    <br>
#
#    $g(k)= 2\cdot \frac{1}{\left(2\pi/L^{3}\right)}\cdot4\pi k^{2} dk=V\cdot\frac{k^{2}}{\pi^{2}}dk$
#
#    <br>
#
#    </div>
# </div>
#
# <div  class="collapse" id="ebazpena5">
#    <div class="alert alert-success" role="alert">
#
#    <br>
#
#    <h2> Ebazpena   </h2>
#
#    </div>
#
# - Ariketak hiru azpiariketa dauzka:
#     1. bosoiz osatutako sistema jakina: *fotoiak*
#         - dispertsio-erlazioa: $\omega(\vec{k})=c\cdot |\vec{k}|\Rightarrow \omega(k)=c\cdot k$
#             $\epsilon= \hbar\cdot\omega \Rightarrow \boxed{\epsilon=\hbar c\cdot k}$
#         - fotoiei dagokien spina da $s=1$, baina bi spin-egoera baino ez dute: $s=\pm 1$
#     2. fermioiz (erlatibistak haiek) osatutako sistema jakina: $\frac{1}{2}$ spineko elektroiak
#         - dispertsio-erlazioa: $\epsilon(\vec{p})=c\cdot |\vec{p}|\Rightarrow \epsilon=c\cdot p$
#             kontuan izan $\vec{p}=\hbar\cdot \vec{k}\Rightarrow p=\hbar \cdot k\Rightarrow \boxed{\epsilon=c\hbar\cdot k}$
#         - finkatutako spinarekin lotuta 2 spin-egoera dago: $s=\pm\frac{1}{2}$
# - `Konturatu:` dispertsio-erlazioak eta spin-egoerak berdinak direla
#
# </div>

# %% [markdown]
# # Template

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
#    <h1>&#9989; 12 Ariketa: kokapena </h1>
#
#    <h2> Ariketaren titulua: <em> </em>   </h2>
#
#    <div>
#    <h2> Helburua:    </h2>
#
#    1. Multzo mikrokanonikoan kalkuluak egiten trebatzen hastea
#    2. Multzo mikrokanonikotik kanonikora *pasatzen* ikastea, esangura fisikoaz konturatuz
#
#    </div>
#
#    <h2> Ikasiko duzuna:  </h2>
#
#
# </div>
#
# <div class="row alert alert-info"  role="alert">
#    <br>
#    <br>
#
#    Aztertu beharreko sistemari dagokion oinarrizko ekuazioa ondokoa da:
#
#    $$D_{3}(\epsilon)=\left[\frac{1}{\left(\frac{\pi}{L}\right)}\left(\frac{2m}{\hbar^{2}}\right)^{\frac{1}{2}}\right]\epsilon^{\frac{1}{2}}$$
#
#    adierazpen horretan $A$ konstante positiboa da.
#
#    Bolumena zortzi aldiz handitu dion espantsio adiabatiko itzulgarriaren ondorioz, zenbatekoa da sisteman gertatu den tenperatura-aldaketa?
#
#    1. kkakak
#    2. lallala
#    3. lslls
#
#    <br>
#    <br>
#
# </div>
#
# <p>
# <button class="btn btn-warning" type="button" disabled data-toggle="collapse" data-target="#emaitza5" aria-expanded="false" aria-controls="collapseExample">
#     Emaitza
# </button>
# <button class="btn btn-info" type="button" disabled data-toggle="collapse" data-target="#pistak5" aria-expanded="false" aria-controls="collapseExample">
#     Pistarik...
# </button>
# <button class="btn btn-success" type="button" disabled data-toggle="collapse" data-target="#ebazpena5" aria-expanded="false" aria-controls="collapseExample">
#     Ebazpen bat...
# </button>
# </p>
#
# <div class="collapse" id="emaitza5">
#    <div class="card card-block">
#    <br>
#
#
#    <br>
#
#    </div>
# </div>
#
# <div class="collapse" id="pistak5">
#    <div class="card card-block">
#
#    <br>
#
#
#    <br>
#
#    </div>
# </div>
#
# <div  class="collapse" id="ebazpena5">
#    <div class="alert alert-success" role="alert">
#
#    <br>
#
#    <h2> Ebazpena   </h2>
#
#    </div>
#
#
# </div>
