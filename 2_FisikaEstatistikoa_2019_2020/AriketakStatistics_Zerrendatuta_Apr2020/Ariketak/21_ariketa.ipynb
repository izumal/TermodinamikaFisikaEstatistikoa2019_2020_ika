# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
#    <h1>&#9989; 21 Ariketa: </h1>
#
#    <h2> Sistema txikia 2:  <em> Betetze nulua edo bikoa. Inpurutasun atomo baten ionizazioa erdieroale batean</em>   </h2>
#
#    <div>
#    <h2> Helburua:    </h2>
#
#    1.
#    2.
#
#    </div>
#
#    <h2> Ikasiko duzuna:  </h2>
#
#
# </div>
#
# <div class="row alert alert-info"  role="alert">
#    <br>
#    <br>
#
# | egoera          | $\textrm{e}^{-}$-en kopurua   | Energia      |
# |-----------------|:------------------------------|-------------:|
# | 1               | ez dago elektroirik    $N=0$  | $\epsilon=0$ |
# | 2               | 1, gorako spinarekin   $N=1$  | $\epsilon=-I$|
# | 3               | 1, beherako spinarekin $N=1$  | $\epsilon=-I$|
#
# 1. Lortu *beteta* egoteko probabilitatea.
#
#    <br>
#    <br>
#
# </div>
#
# <p>
# <button class="btn btn-warning" type="button" disabled data-toggle="collapse" data-target="#emaitza21" aria-expanded="false" aria-controls="collapseExample">
#     Emaitza
# </button>
# <button class="btn btn-info" type="button" disabled data-toggle="collapse" data-target="#pistak21" aria-expanded="false" aria-controls="collapseExample">
#     Pistarik...
# </button>
# <button class="btn btn-success" type="button" disabled data-toggle="collapse" data-target="#ebazpena21" aria-expanded="false" aria-controls="collapseExample">
#     Ebazpen bat...
# </button>
# </p>
#
# <div class="collapse" id="emaitza21">
#    <div class="card card-block">
#    <br>
#
#
#    <br>
#
#    </div>
# </div>
#
# <div class="collapse" id="pistak21">
#    <div class="card card-block">
#
#    <br>
#
#
#    <br>
#
#    </div>
# </div>
#
# <div  class="collapse" id="ebazpena21">
#    <div class="alert alert-success" role="alert">
#
#    <br>
#
#    <h2> Ebazpena   </h2>
#
#    </div>
#
#
# </div>
