# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
#    <h1>&#9989; 48 Ariketa: kokapena </h1>
#
#    <h2> Fermioiak eta Bosoiak 7:  <em> Fluktuazioak Fermi gasean</em>   </h2>
#
#    <div>
#    <h2> Helburua:    </h2>
#
#    1.
#    2.
#
#    </div>
#
#    <h2> Ikasiko duzuna:  </h2>
#
#
# </div>
#
# <div class="row alert alert-info"  role="alert">
#    <br>
#    <br>
#
#    Frogatu, fermioiz osatutako sisteman, *orbital* bakarrari dagokion batez besteko betetzearen kasuan, honako hau betetzen dela:
#
#    $$\langle\left(\Delta N\right)^{2}\rangle = \langle N \rangle \left(1 - \langle N \rangle\right)$$
#
#    Adierazpen horretan $\langle N \rangle$ da aipatutako orbitaleko batez besteko fermioi kopurua.
#
#    <br>
#    <br>
#
# </div>
#
# <p>
# <button class="btn btn-warning" type="button" disabled data-toggle="collapse" data-target="#emaitza48" aria-expanded="false" aria-controls="collapseExample">
#     Emaitza
# </button>
# <button class="btn btn-info" type="button"  data-toggle="collapse" data-target="#pistak48" aria-expanded="false" aria-controls="collapseExample">
#     Pistarik...
# </button>
# <button class="btn btn-success" type="button" disabled data-toggle="collapse" data-target="#ebazpena48" aria-expanded="false" aria-controls="collapseExample">
#     Ebazpen bat...
# </button>
# </p>
#
# <div class="collapse" id="emaitza48">
#    <div class="card card-block">
#    <br>
#
#
#    <br>
#
#    </div>
# </div>
#
# <div class="collapse" id="pistak48">
#    <div class="card card-block">
#
#    <br>
#
#    Honako hau da $\Delta N$ batez bestekoaren definizioa: $\Delta N = N - \langle N \rangle$
#
#    Konturatu zaitez fluktuazioak deuseztatzen direla Fermiren energiatik behera sakon dauden orbitalen kasurako, zeinetan $\langle N \rangle = 1$.
#
#    <br>
#
#    </div>
# </div>
#
# <div  class="collapse" id="ebazpena48">
#    <div class="alert alert-success" role="alert">
#
#    <br>
#
#    <h2> Ebazpena   </h2>
#
#    </div>
#
#
# </div>
