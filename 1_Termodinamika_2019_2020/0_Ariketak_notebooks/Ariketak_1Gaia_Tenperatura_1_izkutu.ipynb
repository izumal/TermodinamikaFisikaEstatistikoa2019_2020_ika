# %% [markdown]
# ## **Termodinamikaren 0. Printzipioa**
#
#
# ## Ariketak  (1-5)

# %% [markdown]
# Ondoren dauden ariketak termodinamikaren Zero Printzipioarekin lotutako ariketak dira. *Zemansky* liburutik ateratakoak dira, esplizituki adierazita dagoen moduan.
#
# **Ariketen helburua**: tenperatura-funtzioaren kontzeptuaz jabetzea eta oreka termikoarekin lotutako adibideak ebazten trebatzea.
#
# Ikusiko duzuenez, elkarren arteko ukipen termikoan esarriko diren sistemak mota berekoak izan daitezke (hots, haien deskribapenean parte hartzen duten aldagaiak mota berekoak dira, askatasun-gradu bereko sistemak izango baitira) edo ez. Azken kasuan, jakina, sistemen deskribapenean parte hartzen dituzten aldagaiak mota desberdinekoak dira, baina edozein kasutan, sistemek izango dute esleituta ***tenperatura-funtzioa***. Oreka termikoan dauden sistemen tenperatura-funtzioek balio beberbera izango dute, oreka termiko, egoera fisiko, berean baitaude. Oreka termikoa adierazteko, tenperatura-funtzioak erabilita, **berdintzak** (ekuazio matematikoak) erabiltzen dira. Horietan dautza ariketak.

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
#
#
# # &#9989;  1. Ariketa (Z 1.1)
#
# ## Oreka termikoa
# ## Tenperatura-funtzioa sistema hidrostatiko ezberdinen kasuan
#
# Ariketa honetan, *sistema hidrostatikoak* dira elkarren arteko oreka termikoan dauden sistemak. Horien deskribapenean parte hartzen dituzten aldagaien sorta honako hau da (). Sistemak desberdintzeko aldagaiak desberdintzen dira.
#
# Oraindik ez dira sistema hidrostatikoak definitu, baina, ariketa hauetarako jakin beharreko gauza bakarra da horien kasuan deskribapenean parte hartzen duten aldagaiak direla honako sortakoak: $p, T (\theta), V$.
#
#
# ## Helburua:
#
#    1. *Oreka termikoa* kontzeptuaz adibideetatik jabetzea
#
#    2. Termodinamikaren 0. Printzipioa erabiltzen trebatzea
#
#
# ##  Ikasiko duzuna:
#
#    1. Zero printzipiotik ondorioztatutko duzu *tenperatura-funtzioa*.
#       Horretarako egin beharreko gauza bakarra da oreka termikoa defintzen duen funtzio inplizitua funtzio ezplituetan banatzea, hots, sistema bakoitzari dagokiona bakantzea
#    <br>
#    2. Nahiz eta sistema mota berdina izan, tenperatura-funtzioa ezberdina izan daiteke.
#       Sistem mota berdina izanik baina sistemak, sistema konkretuak ezberdinak badira, orduan, tenperatura-funtzioak berdinak dira
#    <br>
#    3. Tenperatura-funtzioak, ezberdinak izanik ere, balio berbera dute.
#
#
#
#
# </div>
#
# <div class="row alert alert-info"  role="alert">
#    <br>
#    <br>
#
#
#
# $A$, $B$ eta $C$ gasak dira, ($p$, $V$), ($p'$, $V'$), ($p''$, $V''$) parametro-bikoteen bidez ezaugarritutakoak.
#
# $A$ eta $C$ oreka termikoan dauden kasuan, honako ekuazio hau betetzen da:
# $$pV - nbp - p'' V''  = 0$$
# $B$ eta $C$ oreka termikoan dauden kasuan, ordea, betetzen den ekuazioa honako hau da:
# $$ p\,'V' - p''\,V''  + \frac{n\,B'\,p''\,V''}{V'} = 0 $$
# adierazpen horretan $n$, $B'$ eta $b$ konstanteak dira.
#
# - Zein dira oreka termikoan elkarren berdinak diren funtzioak, non bakoitza $t$ tenperatura enpirikoaren berdina den?
# - Zein da $A$ eta $B$-ren arteko oreka termikoan agertuko den erlazioa?
#
#
#
#
#    <br>
#    <br>
#
# </div>
#
# <p>
# <button class="btn btn-warning" type="button"  data-toggle="collapse" data-target="#emaitza1" aria-expanded="false" aria-controls="collapseExample">
#     Emaitza
# </button>
# <button class="btn btn-info" type="button"  data-toggle="collapse" data-target="#pistak1" aria-expanded="false" aria-controls="collapseExample">
#     Pistarik...
# </button>
# <button class="btn btn-success" type="button"  data-toggle="collapse" data-target="#ebazpena1" aria-expanded="false" aria-controls="collapseExample">
#     Ebazpen bat...
# </button>
# </p>
#
# <div class="collapse" id="emaitza1">
#    <div class="card card-block">
#    <br>
#
#
#
#    <br>
#
#    </div>
# </div>
#
# <div class="collapse" id="pistak26">
#    <div class="card card-block">
#
#    <br>
#
#
#    <br>
#
#    </div>
# </div>
#
# <div  class="collapse" id="ebazpena1">
#    <div class="alert alert-success" role="alert">
#
#    <br>
#
#    <h2> Ebazpena   </h2>
#
#
#
#
#    </div>
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
#
#
#
# # &#9989;  2. Ariketa (Z 1.2)
#
# ## Oreka termikoa
# ## Tenperatura-funtzioa ondorioztatu elkarren artean orekan dauden sistema motak ezberdinak direnean
#
# Ariketa honetan, sistemak  **EZ** dira *sistema hidrostatikoak*: bat bai, baina beste biak ez. Bigarrenak eta hirugarrenak askatasun-gradu magnetikoa(k) dau(z)ka, termikoa izateaz gain. Lehenengoaren deskribapenean parte hartzen dituzten aldagaien sorta honako hau da $(p, T (\theta), V)$. Bigarrenaren eta hirugarrenaren kasuan aldiz, aldagaien sorta honako hau da $(H, T (\theta), M)$.
#
# ## Helburua:
#
#    1. *Oreka termikoa* kontzeptuaz adibideetatik jabetzea
#
#    2. Termodinamikaren 0. Printzipioa erabiltzen trebatzea
#
#
# ##  Ikasiko duzuna:
#
#    1. Zero printzipiotik ondorioztatutko duzu *tenperatura-funtzioa*.
#       Horretarako egin beharreko gauza bakarra da oreka termikoa defintzen duen funtzio inplizitua funtzio ezplituetan banatzea, hots, sistema bakoitzari dagokiona bakantzea
#    <br>
#    2. Nahiz eta sistema mota berdina izan, tenperatura-funtzioa ezberdina izan daiteke.
#       Sistem mota berdina izanik baina sistemak, sistema konkretuak ezberdinak badira, orduan, tenperatura-funtzioak berdinak dira
#    <br>
#    3. Tenperatura-funtzioak, ezberdinak izanik ere, balio berbera dute.
#
#
#
#
# </div>
#
# <div class="row alert alert-info"  role="alert">
#    <br>
#    <br>
#
#
#
# $A$ eta $B$ sistemak ($H$, $M$) eta ($H'$, $M'$) koordenatu-bikoteen bidez deskribatu daitezke. $C$ sistema gasa da, ($p$, $V$) bikotearen bidez ezaugarritutakoa. $A$ eta $C$ oreka termikoan dauden kasuan ondoko ekuazioa beteko da:
# $$ 4\,\pi n\,R\,C_C\,H - M\,p\,V = 0 $$
# $B$ eta $C$ oreka termikoan dauden kasuan, berriz, ondokoa:
# $$ n\,R\,\Theta\,M' + 4\,\pi\,n\,R\,C'_C\,H'  - M'\,p\,V = 0 $$
# adierazpen horretan $n, R, C_c, C_{c^{'}}$ eta $\Theta$ konstanteak dira.
#
# - Zein dira oreka termikoan elkarren berdinak diren funtzioak?
# - Bihurtu horietariko funtzio bakoitza gas idealaren tenperaturaren berdin.
#
#
#    <br>
#    <br>
#
# </div>
#
# <p>
# <button class="btn btn-warning" type="button"  data-toggle="collapse" data-target="#emaitza2" aria-expanded="false" aria-controls="collapseExample">
#     Emaitza
# </button>
# <button class="btn btn-info" type="button"  data-toggle="collapse" data-target="#pistak2" aria-expanded="false" aria-controls="collapseExample">
#     Pistarik...
# </button>
# <button class="btn btn-success" type="button"  data-toggle="collapse" data-target="#ebazpena2" aria-expanded="false" aria-controls="collapseExample">
#     Ebazpen bat...
# </button>
# </p>
#
# <div class="collapse" id="emaitza2">
#    <div class="card card-block">
#    <br>
#
#
#
#
#    <br>
#
#    </div>
# </div>
#
# <div class="collapse" id="pistak2">
#    <div class="card card-block">
#
#    <br>
#
#
#    <br>
#
#    </div>
# </div>
#
# <div  class="collapse" id="ebazpena2">
#    <div class="alert alert-success" role="alert">
#
#    <br>
#
#    <h2> Ebazpena   </h2>
#
#
#
#    </div>
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
#
# # &#9989;  3. Ariketa (Z 1.3)
#
# ## Oreka termikoa
# ## Bolumen konstanteko gas-termometroa
#
# Ariketa honetan gogorarazi nahi da bolumen konstanteko gas-termometroaren (bkgt) erabilera eta gas idealaren tenperatura-eskalaren definizioa. Nahiz eta bkgt-aren tanga egoera termiko berean dagoen egoerarekin ukipen termikoan ezarri, bolumenean bertan sartutako gas kantitatea ezberdina bada, lortuko den tenperaturaren balioa ezberdina izango da. Haatik, gas idealaren limetean, hots, sartutako gas kantitatea oso-oso txikia denean, tenperaturaren balio bakarra lortzen da. Kasu honetan, gas aldatuko bagenu ere bai.
#
#
#
#
# ## Helburua:
#
#    1. Trebatzea eta menderatzea Bolumen konstanteko gas termometroa
#
#    2. Jabetzea egoera termikoei dagokien tenperaturaren balioa ezartzeaz
#
#    3. Tenperaturaren balioaren ezartzeko prozedura orokorraz jabetzea
#
#
# ##  Ikasiko duzuna:
#
#    1. Ikasiko duzu ondo ezberdintzen egoera termikoa eta tenperaturaren balioa: ez dira gauza berbera, hots, egoera termiko berberarekin tenperaturaren hainbat balio lotuta egon daiteke.
#       Baldintza esperimentalen araberakoak dira balaio horiek.
#    <br>
#
#
# </div>
#
# <div class="row alert alert-info"  role="alert">
#    <br>
#    <br>
#
#
#
# Bolumen konstanteko gas-termometroaren gordailuan dagoen gasaren presioa adierazi dute beheko taulako lehenengo lerroko zenbakiek, gordailua uraren puntu hirukoitzean dagoen kasuan. Beheko lerroak, aldiz, gordailuaren presioaren irakurketak adierazi ditu, termometroa beste egoera termikoan dagoenean. Zutabeetan, jakina, boumen-konstanteko gas-termometroan sartutako gas berberaren kantita ezberdinak kokatuta neurtutako presio-balioak daude.
#
# - Lortu substantziari dagokion $\theta$ tenperatura,  gas idealaren tenperatura-eskalan.
#
# | egoera termikoa | $m_1$ | $m_2$ | $m_3$ | $m_4$ |
# | :------------ |:------:|:------:|:------:|:------:|
# | p (mm Hg) PH   | 1000.0 |	750.0  | 500.0  | 250.0  |
# | p (mm Hg)      | 1535.3 |	1151.6 | 767.82 | 383.95 |
#
#
# - **Laguntza**: irudikatu puntuak $\theta\,/p_{PH}$, doitu erregresio lineala erabiliz eta doiketaren *jatorriko ordenatua* izango da oreka termikoari dagokion tenperaturaren balioa.
#
# - Gogoratu honako hau dela tenperaturaren balio gas idealaren tenperatura-eskalan:
# $$\theta = 275.16\,\times\,\lim_{PH\to 0}\frac{p}{p_{PH}} $$
#
#
#    <br>
#    <br>
#
# </div>
#
# <p>
# <button class="btn btn-warning" type="button"  data-toggle="collapse" data-target="#emaitza3" aria-expanded="false" aria-controls="collapseExample">
#     Emaitza
# </button>
# <button class="btn btn-info" type="button"  data-toggle="collapse" data-target="#pistak3" aria-expanded="false" aria-controls="collapseExample">
#     Pistarik...
# </button>
# <button class="btn btn-success" type="button"  data-toggle="collapse" data-target="#ebazpena3" aria-expanded="false" aria-controls="collapseExample">
#     Ebazpen bat...
# </button>
# </p>
#
# <div class="collapse" id="emaitza3">
#    <div class="card card-block">
#    <br>
#
#
#
#
#    <br>
#
#    </div>
# </div>
#
# <div class="collapse" id="pistak3">
#    <div class="card card-block">
#
#    <br>
#
#
#    <br>
#
#    </div>
# </div>
#
# <div  class="collapse" id="ebazpena3">
#    <div class="alert alert-success" role="alert">
#
#    <br>
#
#    <h2> Ebazpena   </h2>
#
#
#    </div>
#
#
# </div>

# %% [markdown]
# Ondoko bi ariketak berdinak dira. Helburua hauxe da: konturatzea orotariko sistemak erabil daitezkeela termometro gisa eta, gainera, bakoitzaren kasuan, defintzen den tenperaturaren balioa ezberdina izan daitekeela. Tenperatura-eskalaren prozedurari erreparatuz, oraingo bi ariketa hauetan beste *sistema mota* bat aukeratu dugu, erresistentzia elektriko (ez da sistema hidrostatikoa, ez da gasa), eta ariketa bakoitzaren kasuan, *sistema jakin* ezberdina dugu: ikatza eta germanio. Erreparatu bien kasuan aldagai termomentrikoa berdina izanik (**erresistentzia elektrikoa**), funtzio termometrikoa ezberdina da.

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
#
# # &#9989;  4. Ariketa (Z 1.4)
#
# ## Oreka termikoa
# ## Erresistentzia elektrikoko termometroa 1
#
#
#
#    <br>
#
#
# </div>
#
# <div class="row alert alert-info"  role="alert">
#    <br>
#    <br>
#
#
# Ikatzezko erresistentziaren $R'$ erresistentziari ondoko ekuazioa esleitu zaio:
# $$ \sqrt {\frac{\log R'}{\theta }}  = a + b\,\log R'$$
# adierazpen horretan $a=-116$ eta $b=0.675$ dira.
#
# - Helio likidozko kriostatoan behatutako erresistentziaren balioa 1000$\,\Omega$ da zehazki. Zenbat da tenperatura?
# - Egin ezazu $R'$ erresistentziari dagokion log/log adierazpide grafikoa $\theta$-ren funtzioan, 1000 $\,\Omega$ eta 30000 $\,\Omega$-eko erresistentzia-tartean.
#
#
#
#    <br>
#    <br>
#
# </div>
#
# <p>
# <button class="btn btn-warning" type="button"  data-toggle="collapse" data-target="#emaitza4" aria-expanded="false" aria-controls="collapseExample">
#     Emaitza
# </button>
# <button class="btn btn-info" type="button"  data-toggle="collapse" data-target="#pistak4" aria-expanded="false" aria-controls="collapseExample">
#     Pistarik...
# </button>
# <button class="btn btn-success" type="button"  data-toggle="collapse" data-target="#ebazpena4" aria-expanded="false" aria-controls="collapseExample">
#     Ebazpen bat...
# </button>
# </p>
#
# <div class="collapse" id="emaitza4">
#    <div class="card card-block">
#    <br>
#
#
#
#    <br>
#
#    </div>
# </div>
#
# <div class="collapse" id="pistak4">
#    <div class="card card-block">
#
#    <br>
#
#
#    <br>
#
#    </div>
# </div>
#
# <div  class="collapse" id="ebazpena4">
#    <div class="alert alert-success" role="alert">
#
#    <br>
#
#    <h2> Ebazpena   </h2>
#
#
#
#
#    </div>
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
#
# # &#9989;  5. Ariketa (Z 1.5)
#
# ## Oreka termikoa
# ## Erresistentzia elektrikoko termometroa 2
#
#
#
#    <br>
#
#
# </div>
#
# <div class="row alert alert-info"  role="alert">
#    <br>
#    <br>
#
# Dopaturiko germaniozko kristalaren erresistentzia adieraziko duen ekuazioa honako hau da:
# $$ \log R'  = 4.697 - 3.917\,\log \theta $$
#
# - Helio likidozko kriostatoan behatutako erresistentziaren balioa 218$\,\Omega$ da. Zenbatekoa da tenperatura?
# - Egin ezazu  $R'$ erresistentziari dagokion log/log adierazpide grafikoa $\theta$-ren funtzioan, 200 $\,\Omega$-ko eta 30000 $\,\Omega$-ko erresistentzia-tartean.
#
#
#
#    <br>
#    <br>
#
# </div>
#
# <p>
# <button class="btn btn-warning" type="button"  data-toggle="collapse" data-target="#emaitza5" aria-expanded="false" aria-controls="collapseExample">
#     Emaitza
# </button>
# <button class="btn btn-info" type="button"  data-toggle="collapse" data-target="#pistak5" aria-expanded="false" aria-controls="collapseExample">
#     Pistarik...
# </button>
# <button class="btn btn-success" type="button"  data-toggle="collapse" data-target="#ebazpena5" aria-expanded="false" aria-controls="collapseExample">
#     Ebazpen bat...
# </button>
# </p>
#
# <div class="collapse" id="emaitza5">
#    <div class="card card-block">
#    <br>
#
#
#
#
#    <br>
#
#    </div>
# </div>
#
# <div class="collapse" id="pistak5">
#    <div class="card card-block">
#
#    <br>
#
#
#    <br>
#
#    </div>
# </div>
#
# <div  class="collapse" id="ebazpena5">
#    <div class="alert alert-success" role="alert">
#
#    <br>
#
#    <h2> Ebazpena   </h2>
#
#
#
#
#    </div>
#
#
# </div>
